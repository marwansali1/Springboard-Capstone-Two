# %%
# Organizing the data to streamline all the projects (capstone) steps
# Importing all the required packages for data wrangling
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# loading and checking the dataset
df = pd.read_csv('US_Accidents_Dec21_updated.csv ')
print(df)
# Out:
#                 ID  Severity           Start_Time             End_Time  \
# 0              A-1         3  2016-02-08 00:37:08  2016-02-08 06:37:08
# 1              A-2         2  2016-02-08 05:56:20  2016-02-08 11:56:20
# 2              A-3         2  2016-02-08 06:15:39  2016-02-08 12:15:39
# 3              A-4         2  2016-02-08 06:51:45  2016-02-08 12:51:45
# 4              A-5         3  2016-02-08 07:53:43  2016-02-08 13:53:43
# ...            ...       ...                  ...                  ...
# 2845337  A-2845338         2  2019-08-23 18:03:25  2019-08-23 18:32:01
# 2845338  A-2845339         2  2019-08-23 19:11:30  2019-08-23 19:38:23
# 2845339  A-2845340         2  2019-08-23 19:00:21  2019-08-23 19:28:49
# 2845340  A-2845341         2  2019-08-23 19:00:21  2019-08-23 19:29:42
# 2845341  A-2845342         2  2019-08-23 18:52:06  2019-08-23 19:21:31
#
#          Start_Lat   Start_Lng    End_Lat     End_Lng  Distance(mi)  \
# ...

# %%
# A new repository was added to Github for this project, to gain an understanding of the data; we're going to check the columns names, data types, discription of the columns, counting and checking the percents of the unique values, and their ranges.
df.head()
# Out:
#     ID  Severity           Start_Time             End_Time  Start_Lat  \
# 0  A-1         3  2016-02-08 00:37:08  2016-02-08 06:37:08  40.108910
# 1  A-2         2  2016-02-08 05:56:20  2016-02-08 11:56:20  39.865420
# 2  A-3         2  2016-02-08 06:15:39  2016-02-08 12:15:39  39.102660
# 3  A-4         2  2016-02-08 06:51:45  2016-02-08 12:51:45  41.062130
# 4  A-5         3  2016-02-08 07:53:43  2016-02-08 13:53:43  39.172393
#
#    Start_Lng    End_Lat    End_Lng  Distance(mi)  \
# 0 -83.092860  40.112060 -83.031870         3.230
# 1 -84.062800  39.865010 -84.048730         0.747
# 2 -84.524680  39.102090 -84.523960         0.055
# 3 -81.537840  41.062170 -81.535470         0.123
# 4 -84.492792  39.170476 -84.501798         0.500
#
#                                          Description  ...  Roundabout Station  \
# 0  Between Sawmill Rd/Exit 20 and OH-315/Olentang...  ...       False   False
# 1                 At OH-4/OH-235/Exit 41 - Accident.  ...       False   False
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Severity', 'Start_Time', 'End_Time', 'Start_Lat', 'Start_Lng',
#        'End_Lat', 'End_Lng', 'Distance(mi)', 'Description', 'Number', 'Street',
#        'Side', 'City', 'County', 'State', 'Zipcode', 'Country', 'Timezone',
#        'Airport_Code', 'Weather_Timestamp', 'Temperature(F)', 'Wind_Chill(F)',
#        'Humidity(%)', 'Pressure(in)', 'Visibility(mi)', 'Wind_Direction',
#        'Wind_Speed(mph)', 'Precipitation(in)', 'Weather_Condition', 'Amenity',
#        'Bump', 'Crossing', 'Give_Way', 'Junction', 'No_Exit', 'Railway',
#        'Roundabout', 'Station', 'Stop', 'Traffic_Calming', 'Traffic_Signal',
#        'Turning_Loop', 'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight'],
#       dtype='object')

# %%
# After getting the results above, the action needed are as follows:
# Checking the 'county' and 'country' columns.
# Checking the thrre types of twillight columns ("Civil_Twilight", "Nautical_Twilight" and "Astronomical_Twilight")
# Checking the similar columns types ('Street', 'Side', 'City', 'County', 'State', 'Zipcode', 'Country')
# Now, we're going to create two columns, one to store list of features to drop and one to add features that are need to be added
drop_list=[]
feature_list=[]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2845342 entries, 0 to 2845341
# Data columns (total 47 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   ID                     object
#  1   Severity               int64
#  2   Start_Time             object
#  3   End_Time               object
#  4   Start_Lat              float64
#  5   Start_Lng              float64
#  6   End_Lat                float64
#  7   End_Lng                float64
#  8   Distance(mi)           float64
#  9   Description            object
#  10  Number                 float64
#  11  Street                 object
#  12  Side                   object
#  13  City                   object
#  14  County                 object
#  15  State                  object
#  16  Zipcode                object
#  17  Country                object
#  18  Timezone               object
#  19  Airport_Code           object
#  20  Weather_Timestamp      object
# ...

# %%
# Checking the similar columns types ('Street', 'Side', 'City', 'County', 'State', 'Zipcode', 'Country')
# Checking for the redundancy
df[['Number', 'Street', 'Side', 'City', 'County', 'State', 'Zipcode', 'Country']]
# Out:
#          Number            Street Side         City          County State  \
# 0           NaN       Outerbelt E    R       Dublin        Franklin    OH
# 1           NaN            I-70 E    R       Dayton      Montgomery    OH
# 2           NaN            I-75 S    R   Cincinnati        Hamilton    OH
# 3           NaN            I-77 N    R        Akron          Summit    OH
# 4           NaN            I-75 S    R   Cincinnati        Hamilton    OH
# ...         ...               ...  ...          ...             ...   ...
# 2845337     NaN      Pomona Fwy E    R    Riverside       Riverside    CA
# 2845338     NaN             I-8 W    R    San Diego       San Diego    CA
# 2845339     NaN  Garden Grove Fwy    R       Orange          Orange    CA
# 2845340     NaN   San Diego Fwy S    R  Culver City     Los Angeles    CA
# 2845341     NaN          CA-210 W    R     Highland  San Bernardino    CA
#
#         Zipcode Country
# 0         43017      US
# 1         45424      US
# ...

# %%
# Checking all columns with numbers so as to check the NAN values
df['Number'].isnull().sum() / len(df)
# Out:
# 0.6129003121593116

# %%
drop_list.append('Number')

# %%
df['Street'].nunique()
# Out:
# 159651

# %%
drop_list.append('Street')

# %%
df['Side'].value_counts()
# Out:
# R    2353309
# L     492032
# N          1
# Name: Side, dtype: int64

# %%
df.drop(df.loc[df['Side']=='N'].index,inplace=True)

# %%
df['Side'].value_counts()
# Out:
# R    2353309
# L     492032
# Name: Side, dtype: int64

# %%
# Checking the number of accidents per City and see the ranking
city_by_accidents = df['City'].value_counts()
df['City'].value_counts()
# Out:
# Miami                           106966
# Los Angeles                      68956
# Orlando                          54691
# Dallas                           41979
# Houston                          39448
#                                  ...
# Ridgedale                            1
# Sekiu                                1
# Wooldridge                           1
# Bullock                              1
# American Fork-Pleasant Grove         1
# Name: City, Length: 11681, dtype: int64

# %%
df['City'].nunique()
# Out:
# 11681

# %%
len(city_by_accidents[city_by_accidents>=10000])
high_accident_city = city_by_accidents[city_by_accidents>=10000]
high_accident_city
# Out:
# Miami              106966
# Los Angeles         68956
# Orlando             54691
# Dallas              41979
# Houston             39448
# Charlotte           33152
# Sacramento          32559
# San Diego           26627
# Raleigh             22840
# Minneapolis         22768
# Portland            20944
# Nashville           20267
# Austin              18301
# Baton Rouge         18182
# Phoenix             17143
# Saint Paul          16869
# New Orleans         16251
# Atlanta             15622
# Jacksonville        14967
# Richmond            14349
# Tucson              13799
# San Jose            13377
# Riverside           13310
# Kansas City         13298
# Bakersfield         12044
# San Bernardino      11249
# Chicago             11188
# Tampa               10984
# Salt Lake City      10709
# Ontario             10538
# Anaheim             10502
# Hialeah             10398
# Fort Lauderdale     10345
# Oakland             10051
# Name: City, dtype: int64

# %%
# Data has been checked for the cleanness and duplicates; now is the turn to check missing values.
# First, will get a brief discriptive information
df.describe()
# Out:
#            Severity     Start_Lat     Start_Lng       End_Lat       End_Lng  \
# count  2.845341e+06  2.845341e+06  2.845341e+06  2.845341e+06  2.845341e+06
# mean   2.137572e+00  3.624520e+01 -9.711463e+01  3.624532e+01 -9.711438e+01
# std    4.787217e-01  5.363798e+00  1.831782e+01  5.363874e+00  1.831763e+01
# min    1.000000e+00  2.456603e+01 -1.245481e+02  2.456601e+01 -1.245457e+02
# 25%    2.000000e+00  3.344517e+01 -1.180331e+02  3.344628e+01 -1.180333e+02
# 50%    2.000000e+00  3.609861e+01 -9.241808e+01  3.609798e+01 -9.241764e+01
# 75%    2.000000e+00  4.016024e+01 -8.037243e+01  4.016105e+01 -8.037338e+01
# max    4.000000e+00  4.900058e+01 -6.711317e+01  4.907500e+01 -6.710924e+01
#
#        Distance(mi)        Number  Temperature(F)  Wind_Chill(F)  \
# count  2.845341e+06  1.101431e+06    2.776068e+06   2.375699e+06
# mean   7.026777e-01  8.089408e+03    6.179356e+01   5.965823e+01
# std    1.560361e+00  1.836009e+04    1.862263e+01   2.116097e+01
# ...

# %%
# Checking the missing percents
numeric_df = df.select_dtypes(include='number')
numeric_df.columns
# Out:
# Index(['Severity', 'Start_Lat', 'Start_Lng', 'End_Lat', 'End_Lng',
#        'Distance(mi)', 'Number', 'Temperature(F)', 'Wind_Chill(F)',
#        'Humidity(%)', 'Pressure(in)', 'Visibility(mi)', 'Wind_Speed(mph)',
#        'Precipitation(in)'],
#       dtype='object')

# %%
 # Organizing the missing percent values in an ascending order
missing_percent = df.isna().sum().sort_values(ascending = False)/len(df)
missing_percent
# Out:
# Number                   6.129002e-01
# Precipitation(in)        1.931076e-01
# Wind_Chill(F)            1.650565e-01
# Wind_Speed(mph)          5.550934e-02
# Wind_Direction           2.592800e-02
# Humidity(%)              2.568796e-02
# Weather_Condition        2.482479e-02
# Visibility(mi)           2.479316e-02
# Temperature(F)           2.434612e-02
# Pressure(in)             2.080559e-02
# Weather_Timestamp        1.783090e-02
# Airport_Code             3.355661e-03
# Timezone                 1.285610e-03
# Nautical_Twilight        1.007612e-03
# Civil_Twilight           1.007612e-03
# Sunrise_Sunset           1.007612e-03
# Astronomical_Twilight    1.007612e-03
# Zipcode                  4.632134e-04
# City                     4.814889e-05
# Street                   3.514517e-07
# Country                  0.000000e+00
# Junction                 0.000000e+00
# Start_Time               0.000000e+00
# End_Time                 0.000000e+00
# Start_Lat                0.000000e+00
# ...

# %%
missing_percent[missing_percent != 0]
# Out:
# Number                   6.129002e-01
# Precipitation(in)        1.931076e-01
# Wind_Chill(F)            1.650565e-01
# Wind_Speed(mph)          5.550934e-02
# Wind_Direction           2.592800e-02
# Humidity(%)              2.568796e-02
# Weather_Condition        2.482479e-02
# Visibility(mi)           2.479316e-02
# Temperature(F)           2.434612e-02
# Pressure(in)             2.080559e-02
# Weather_Timestamp        1.783090e-02
# Airport_Code             3.355661e-03
# Timezone                 1.285610e-03
# Nautical_Twilight        1.007612e-03
# Civil_Twilight           1.007612e-03
# Sunrise_Sunset           1.007612e-03
# Astronomical_Twilight    1.007612e-03
# Zipcode                  4.632134e-04
# City                     4.814889e-05
# Street                   3.514517e-07
# dtype: float64

# %%
# Summary
# The number column has been dropped as it has more than (50%) missing values (62%).
# The street column also has been dropped because it has so many unique features.
# The side columns had one N value that was removed. It also showed that most accidents toke place in the right side (more than 82%)!
# Miami has the largest number of accidents and it ranked number one. Miami also the number three populus city in the US, which is clearly justifies that, and sure we are going to get interseting information to help this in the EDA stage.
# Other cities like LA has the same growth rate population wise but also has lower accidents numbers and in comparison with Miami, it considered toolow. We need to check further behind the population information as it is not the main reason as it appeares from the side research.
# Further lookin into counties information and the State information is required in EDA.
